# %% [markdown]
# **Project 1 – Role Control Lab: Custom vs. Built-In Role Exploration**
#
# **🎯 Project Objective**
# Demonstrate the differences between a custom Microsoft Entra role and a built-in role (User Administrator) by assigning each to a separate test user. Evaluate role boundaries, effective permissions, and visibility in the Microsoft Entra portal—simulated through detailed AI-guided steps and facsimile screenshots.
#
# **🔧 Scenario Setup**
# You are managing a tenant where two IT administrators have different responsibilities:
#
# Alice (custom role): Should only view user profile information without making changes.
#
# Bob (built-in role): Should manage users, including resets and assignments.
#
# You will simulate the creation of Alice's custom role and compare her experience to Bob's with the User Administrator role.
#
# **🧪 Step-by-Step Simulation**
# **1. Simulate Access to Microsoft Entra Admin Center**
#
# Path:
# Microsoft Entra Admin Center → Roles and administrators
#
# You are now seeing the list of built-in and custom roles.
#
# **2. Create Custom Role – "User Read Only"**
# Simulated UI Actions:
#
# Select + New custom role
#
# Name: User Read Only
#
# Description: Allows viewing user profiles without modification rights
#
# Permissions → Search: user.read.all
#
# Add only this permission.
#
# Visualize This Facsimile Page:
#
# [Role Name: _____________ ]   ← User Read Only
# [Description: ______________ ] ← View-only access to user objects
# [+ Add Permissions] ← Search: user.read.all
# [✓ user.read.all (Directory)]
# Click Next, then Create.
#
# **3. Assign Roles to Users**
# Facsimile Admin Path:
#
# Microsoft Entra Admin Center → Users → Select Alice
# → Assigned Roles → + Add assignment → Select User Read Only → Save
#
# Repeat for Bob, but assign User Administrator (built-in).
#
# **4. Simulate Login as Alice (Custom Role User)**
# Alice logging into the Entra Admin Center:
#
# She navigates to Users
#
# She sees the list of users
#
# She can view usernames, job titles, and object IDs
#
# She cannot reset passwords, assign roles, or delete accounts
#
# 🟦 Facsimile Error Prompt:
#
# ❌ Action not allowed
# You don’t have permission to perform this action. Contact your admin.
#
# **5. Simulate Login as Bob (User Administrator)**
# Bob logs into the Admin Center:
#
# Navigates to Users
#
# Views all user properties
#
# Can reset passwords, assign roles, and delete users
#
# Has full control under the User Administrator scope
#
# 6. Role Behavior Table (Compare Outcomes)
# Action	Alice (Custom Role)	Bob (User Admin)
# View user list	✅ Yes	✅ Yes
# View user profile	✅ Yes	✅ Yes
# Reset password	❌ No	✅ Yes
# Assign user role	❌ No	✅ Yes
# Delete user	❌ No	✅ Yes
# View group membership	✅ Limited	✅ Full
#
# 7. Effective Permissions Check (Facsimile View)
# Simulate going to:
#
# Microsoft Entra Admin Center → Roles and administrators → User Read Only
# → Tab: Permissions
# → See only user.read.all
#
# Simulate:
# Users → Alice → Assigned Roles → View summary of effective permissions
#
# 📘 What This Project Demonstrates
# How Microsoft Graph API permissions (e.g., user.read.all) define scope and control
#
# That custom roles allow precision but require awareness of limitations
#
# The power of built-in roles—and how they may overgrant for minimal tasks
#
# How to interpret role behavior from the Admin Center UI
